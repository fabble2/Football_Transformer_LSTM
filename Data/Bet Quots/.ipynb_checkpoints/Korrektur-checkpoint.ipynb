# %%
import numpy as np
import pandas as pd
from collections import defaultdict
from difflib import SequenceMatcher
import difflib
from unidecode import  unidecode
from urllib.parse import unquote
import pickle
import csv

# %%
#Correction part
"""
input: pkl file 
in pkl file search for matchday number, teams
take teams/number with odds in form ['-</s', '-</s', '-</s']
search in CSV for match and submit quotas
Collect all erroneous quotas from the pkl
"""
def Fehler_einlesen(jahr):
    templiste=[]
    dokument= "Wettquoten"+str(jahr)+".pkl"
    with (open(dokument, "rb")) as openfile:
        while True:
            try:
                spiel=[]
                wetten= pickle.load(openfile)
                #print(wetten[3])
                if wetten[3]==['-</s', '-</s', '-</s']:
                    spiel.append(wetten[0])
                    spiel.append(wetten[1])
                    spiel.append(wetten[2])
                    templiste.append(spiel)
            except EOFError:
                break
    return templiste
    
"""
input: matchday number, year
Get game days in which the incorrect quota is located
input: game number and season year
output: List from [team1, team2, [odds]], 9 entries (one matchday)
"""
def Korrektur(spieltagsnummer,jahr):
    
    #print(data)
    spieldaten=[]
    ersteZeile=1  
    spieltag= spieltagsnummer
    anfang= (spieltag-1)*9
    ende= spieltag*9
    counter=0
    zahl= str(jahr)
    file= zahl[-2:]+".csv"
    with open(file, 'r') as read_obj:
        csv_reader = csv.reader(read_obj)
        for row in csv_reader:
            
            if ersteZeile==1:
                ersteZeile=0
                continue
            odds=[]
            spiel=[]
            if counter< ende and counter >=anfang:

                odds.append(row[22])
                odds.append(row[23])
                odds.append(row[24])
                #print(row[22],row[23],row[24])
                #print(row[2],row[3],odds)
                spiel.append(row[2])
                spiel.append(row[3])
                spiel.append(odds)
                spieldaten.append(spiel)
            counter+=1
    return spieldaten

"""
Similarity search
Get the right team with their nickname/names 
"""
def similar(mannschaft, liste):
    wert=0
    currentteam="nichts"
    for team in liste:
        similarity= SequenceMatcher(None, mannschaft, team).ratio()
        #print(team, similarity)
        if wert < similarity:
            wert= similarity
            currentteam= team
    #print(currentteam)        
    return currentteam

"""
input: pkl
get the correct values for the faulty game,
output: List with the corrected games
"""
def Ausfuehren(pkl):
    pkl_neu=[]
    for data in pkl:
        csv= Korrektur(data[0],jahr)
        teams=[]
        for mannschaft in csv:
            teams.append(mannschaft[0])
            teams.append(mannschaft[1])
        current=(similar(data[1],teams))
        
        for mannschaft in csv:
            if current in mannschaft:
                data.append(mannschaft[2])
    return pkl
        
"""
Create new pickle
Save old pickle in list
New pickle from old list, but the incorrect games replaced by the corrected ones
games replaced
"""
def create_pickle(jahr,neue_werte):
    sammlung= []
    zahl= str(jahr)
    filename= "Wettquoten"+zahl+".pkl"
    with (open(filename, "rb")) as openfile:
            while True:
                try:
                    wetten= pickle.load(openfile)
                    sammlung.append(wetten)s

                except EOFError:
                    break
    for i in sammlung: 
        for j in neue_werte:
            if i[0]== j[0] and i[1]==j[1] and i[2]==j[2]:
                index= sammlung.index(i)
                sammlung[index]=j
    test= sammlung[:307]
    df= pd.DataFrame(test)
    filenamenew= "Wettquoten"+zahl+"Neu.pkl"
    df.to_pickle(filenamenew)
    
    
#jahr=2020       
#pkl_data = Fehler_einlesen(jahr)    
#neue_werte= Ausfuehren(pkl_data)
#create_pickle(jahr,neue_werte)
